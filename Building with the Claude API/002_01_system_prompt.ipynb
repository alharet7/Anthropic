# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()

# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"


def add_user_message(messages, text):
    user_Message= {"role": "user", "content": text}
    messages.append(user_Message)

def add_assistant_message(messages, text):
    assistant_Message= {"role": "assistant", "content": text}
    messages.append(assistant_Message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

add_user_message(messages, "How do I solve 5x + 3 = 2 for x?")

answer = chat(messages, system=system)

answer
# Out:
# "Let's work through this step by step!\n\nYour goal is to **isolate x** - get x by itself on one side of the equation.\n\n**First, look at the equation:** 5x + 3 = 2\n\nWhat do you think you should do **first** to start moving things away from the x side?\n\n*Hint: There's a number being **added** to the 5x term. What could you do to remove it?*"
