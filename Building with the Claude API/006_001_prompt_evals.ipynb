# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    response = chat(messages, stop_sequences=["```"])
    return json.loads(response)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=4)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# def run_tst_case(test_case):
#     """Runs a single test case and returns the result"""
#     output = run_prompt(test_case)
#     return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)
    
results = run_eval(dataset)

# %%
print(json.dumps(results, indent=4))
# Out:
# [
#     {
#         "output": "# AWS S3 Bucket Name Parser\n\nHere's a Python function that parses the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Parse and return the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): An S3 URI in the format 's3://bucket-name/path/to/object'\n        \n    Returns:\n        str: The S3 bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n        \n    Examples:\n        >>> parse_s3_bucket_name('s3://my-bucket/path/to/object')\n        'my-bucket'\n        >>> parse_s3_bucket_name('s3://my-bucket/')\n        'my-bucket'\n        >>> parse_s3_bucket_name('s3://my-bucket')\n        'my-bucket'\n    \"\"\"\n    if not s3_uri:\n        raise ValueError(\"S3 URI cannot be empty\")\n    \n    # Check if URI starts with 's3://'\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}. Must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Extract bucket name (part before the first '/')\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    # Validate bucket name is not empty\n    if not bucket_name:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}. No bucket name found\")\n    \n    return bucket_name\n```\n\n## Usage Examples\n\n```python\n# Basic usage\nprint(parse_s3_bucket_name('s3://my-bucket/path/to/object'))\n# Output: 'my-bucket'\n\nprint(parse_s3_bucket_name('s3://my-bucket/'))\n# Output: 'my-bucket'\n\nprint(parse_s3_bucket_name('s3://my-bucket'))\n# Output: 'my-bucket'\n\n# With complex paths\nprint(parse_s3_bucket_name('s3://data-lake-2024/analytics/reports/Q1/sales.csv'))\n# Output: 'data-lake-2024'\n\n# Error handling\ntry:\n    parse_s3_bucket_name('https://my-bucket/object')\nexcept ValueError as e:\n    print(f\"Error: {e}\")\n    # Output: Error: Invalid S3 URI. Must start with 's3://'\n```\n\n## Alternative: Using Regular Expressions\n\nIf you prefer a regex-based approach:\n\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri: str) -> str:\n    \"\"\"\n    Parse S3 bucket name using regex pattern matching.\n    \n    Args:\n        s3_uri (str): An S3 URI in the format 's3://bucket-name/path'\n        \n    Returns:\n        str: The S3 bucket name\n        \n    Raises:\n        ValueError: If the URI doesn't match the S3 URI pattern\n    \"\"\"\n    match = re.match(r'^s3://([a-z0-9.-]+)', s3_uri)\n    if not match:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    return match.group(1)\n\n# Usage\nprint(parse_s3_bucket_name_regex('s3://my-bucket/path/to/object'))\n# Output: 'my-bucket'\n```\n\n## Test Suite\n\n```python\nimport pytest\n\ndef test_parse_s3_bucket_name():\n    \"\"\"Test the S3 bucket parser function\"\"\"\n    # Valid cases\n    assert parse_s3_bucket_name('s3://my-bucket/path/to/object') == 'my-bucket'\n    assert parse_s3_bucket_name('s3://my-bucket/') == 'my-bucket'\n    assert",
#         "test_case": {
#             "task": "Write a Python function that parses an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/object') and returns just the bucket name."
#         },
#         "score": 10
#     },
#     {
#         "output": "# AWS IAM Policy for S3 Bucket Access\n\nHere's a JSON object representing an IAM policy that allows read and write access to the 'data-lake' S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\",\n        \"s3:DeleteObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-lake/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-lake\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n**Statement 1 - Object Operations:**\n- `s3:GetObject` - Read/download objects from the bucket\n- `s3:PutObject` - Write/upload objects to the bucket\n- `s3:DeleteObject` - Delete objects (commonly needed with write access)\n- Resource: `arn:aws:s3:::data-lake/*` - Applies to all objects within the bucket\n\n**Statement 2 - Bucket Listing:**\n- `s3:ListBucket` - List contents of the bucket\n- Resource: `arn:aws:s3:::data-lake` - Applies to the bucket itself\n\n## Minimal Version (Read & Write Only)\n\nIf you want to exclude delete permissions:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:PutObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-lake/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": \"s3:ListBucket\",\n      \"Resource\": \"arn:aws:s3:::data-lake\"\n    }\n  ]\n}\n```",
#         "test_case": {
#             "task": "Create a JSON object representing an AWS IAM policy that allows a user to read and write objects in a specific S3 bucket named 'data-lake'."
#         },
#         "score": 10
#     },
#     {
#         "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Breakdown\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix \"i-\" |\n| `[0-9a-f]` | Character class matching any hexadecimal digit (0-9, a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid matches \u2713\n- `i-1234567890abcdef0`\n- `i-0a1b2c3d4e5f6g7h8`\n- `i-ffffffffffffffff0`\n\n### Invalid matches \u2717\n- `i-123456789abcdef0` (only 16 hex chars)\n- `i-1234567890abcdef0g` (18 hex chars, plus invalid 'g')\n- `i-1234567890ABCDEF0` (uppercase - if case-sensitive)\n- `ec2-1234567890abcdef0` (wrong prefix)\n\n## Case-Insensitive Version\n\nIf you need to match both uppercase and lowercase:\n\n```regex\n^i-[0-9a-fA-F]{17}$\n```\n\nOr with the case-insensitive flag:\n```regex\n^i-[0-9a-f]{17}$\n```\nwith the `i` flag enabled (varies by language/tool)",
#         "test_case": {
#             "task": "Write a regular expression that matches valid AWS EC2 instance IDs, which follow the format of 'i-' followed by 17 hexadecimal characters (e.g., 'i-1234567890abcdef0')."
#         },
#         "score": 10
#     }
# ]
